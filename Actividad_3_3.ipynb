# %% [markdown]
# <a href="https://colab.research.google.com/github/BetoxAlka/ExtraccionDatos/blob/main/Actividad_3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv o xlsx desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ae31ae0b-6d8c-46b7-8ff2-dddb317941a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae31ae0b-6d8c-46b7-8ff2-dddb317941a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Carga desde un archivo .xlsx sin indice
df = pd.read_excel('Inmuebles.xlsx')
df.head(5)
# Out:
#   Esta es una base de datos que describe las operaciones inmobiliarias de una empresa  \
# 0                                         Referencia
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#             Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0           Fecha_Alta       Tipo  Operación  Provincia  Superficie
# 1  2004-01-01 00:00:00    Parking   Alquiler     Lleida         291
# 2  2004-01-01 00:00:00      Local      Venta     Girona         185
# 3  2004-01-01 00:00:00    Oficina   Alquiler     Girona          82
# 4  2004-01-02 00:00:00    Parking   Alquiler     Girona         285
#
#      Unnamed: 6           Unnamed: 7 Unnamed: 8
# 0  Precio Venta          Fecha Venta   Vendedor
# 1       2133903  2004-06-19 00:00:00     Carmen
# 2       1945424  2004-04-19 00:00:00      Pedro
# ...

# %%
#Eliminar primera fila o filas innecesarias
df = pd.read_excel('Inmuebles.xlsx',skiprows=1) #Al generar el frame, se ignora la fila con las columnas UNNAMED
df
# Out:
#       Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0              1 2004-01-01     Parking  Alquiler     Lleida       291.0
# 1              2 2004-01-01       Local     Venta     Girona       185.0
# 2              3 2004-01-01     Oficina  Alquiler     Girona        82.0
# 3              4 2004-01-02     Parking  Alquiler     Girona       285.0
# 4              5 2004-01-02       Suelo     Venta  Tarragona       152.0
# ...          ...        ...         ...       ...        ...         ...
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334 2007-04-29        Piso  Alquiler     Girona        55.0
# 3334        3335 2007-04-30       Suelo     Venta  Tarragona        78.0
# 3335        3336 2007-04-30        Piso  Alquiler  Barcelona        88.0
# 3336        3337 2007-04-30     Parking     Venta     Lleida       254.0
#
#       Precio Venta Fecha Venta Vendedor
# 0        2133903.0  2004-06-19   Carmen
# ...

# %%
#Eliminar columnas innecesarias
#axis = 1 para columnas
#axis = 0 para filas
df1 = df.drop(['Referencia'], axis=1) #El nuevo frame NO contiene la columna 0, por lo que falta eliminar la columna Referncia
df1
# Out:
#      Fecha_Alta        Tipo Operación  Provincia  Superficie  Precio Venta  \
# 0    2004-01-01     Parking  Alquiler     Lleida       291.0     2133903.0
# 1    2004-01-01       Local     Venta     Girona       185.0     1945424.0
# 2    2004-01-01     Oficina  Alquiler     Girona        82.0           NaN
# 3    2004-01-02     Parking  Alquiler     Girona       285.0           NaN
# 4    2004-01-02       Suelo     Venta  Tarragona       152.0      185000.0
# ...         ...         ...       ...        ...         ...           ...
# 3332 2007-04-29  Industrial  Alquiler     Lleida       221.0     1450644.0
# 3333 2007-04-29        Piso  Alquiler     Girona        55.0      454080.0
# 3334 2007-04-30       Suelo     Venta  Tarragona        78.0      740688.0
# 3335 2007-04-30        Piso  Alquiler  Barcelona        88.0      397408.0
# 3336 2007-04-30     Parking     Venta     Lleida       254.0     2140712.0
#
#      Fecha Venta Vendedor
# 0     2004-06-19   Carmen
# ...

# %%
#Convertir archivo filtrado a csv
df1.to_csv('Filtro1.csv')

from google.colab import files

files.download('Filtro1.csv')

# %%
filtro2 = df1[(df1['Fecha_Alta'] == '2007-04-29') | (df1['Fecha_Alta'] == '2004-01-02')] #Filtrado por las fechas 2007-04-29 y 2004-01-02
filtro2
# Out:
#      Fecha_Alta        Tipo Operación  Provincia  Superficie  Precio Venta  \
# 3    2004-01-02     Parking  Alquiler     Girona       285.0           NaN
# 4    2004-01-02       Suelo     Venta  Tarragona       152.0      185000.0
# 3331 2007-04-29     Oficina     Venta     Lleida       190.0     1031320.0
# 3332 2007-04-29  Industrial  Alquiler     Lleida       221.0     1450644.0
# 3333 2007-04-29        Piso  Alquiler     Girona        55.0      454080.0
#
#      Fecha Venta Vendedor
# 3     2004-04-27    Jesús
# 4     2004-07-10    María
# 3331         NaT      NaN
# 3332         NaT      NaN
# 3333         NaT      NaN

# %%
#Convertir archivo filtrado a csv
filtro2.to_csv('Filtro2.csv')

from google.colab import files

files.download('Filtro2.csv')

# %%
filtro3 = df1[(df1['Tipo'] == 'Parking') | (df1['Tipo'] == 'Local') | (df1['Tipo'] == 'Industrial') | (df1['Tipo'] == 'Piso')]
filtro3 #Filtro mediante tipo de parking, local, industrial y piso
# Out:
#      Fecha_Alta        Tipo Operación  Provincia  Superficie  Precio Venta  \
# 0    2004-01-01     Parking  Alquiler     Lleida       291.0     2133903.0
# 1    2004-01-01       Local     Venta     Girona       185.0     1945424.0
# 3    2004-01-02     Parking  Alquiler     Girona       285.0           NaN
# 5    2004-01-03  Industrial  Alquiler     Girona       131.0      953156.0
# 6    2004-01-03     Parking  Alquiler  Tarragona         NaN      406686.0
# ...         ...         ...       ...        ...         ...           ...
# 3330 2007-04-27       Local     Venta     Girona       110.0      845790.0
# 3332 2007-04-29  Industrial  Alquiler     Lleida       221.0     1450644.0
# 3333 2007-04-29        Piso  Alquiler     Girona        55.0      454080.0
# 3335 2007-04-30        Piso  Alquiler  Barcelona        88.0      397408.0
# 3336 2007-04-30     Parking     Venta     Lleida       254.0     2140712.0
#
#      Fecha Venta Vendedor
# 0     2004-06-19   Carmen
# ...

# %%
#Convertir archivo filtrado a csv
filtro3.to_csv('Filtro3.csv')

from google.colab import files

files.download('Filtro3.csv')
